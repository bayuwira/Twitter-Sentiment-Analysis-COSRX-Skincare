# %%
import tweepy
import json
import pymongo
from pymongo import MongoClient
import sys
import os
import twitter
import GetOldTweets3 as got
import snscrape.modules.twitter as snstwitter

# %%
CONSUMER_KEY = "ER6dm8K9Y2gGm4w3vHhJIxy8o"
CONSUMER_SECRET = "InYaTVJjmIsG3PMp5nKOU6bMUXIyT7kHoJXtVXxsLYh9w1YOS5"
ACCESS_TOKEN = "1330751702136365056-doRSWEBA00wZzOL03hXVMI5qTP2cDe"
ACCESS_TOKEN_SECRET = "ZxCgwpV05w4cjRbUlhPyajUvvSwL5E9bZqVUQxjRTAE1c"

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

rest_api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
if (not rest_api):
    sys.exit('Autentikasi gagal')
else:
    print("Berasil")
# Out:
# Berasil

# %%
client = MongoClient('localhost', 27017)
db = client['scarlett_db']
collection = db['crawling_2']
collection.create_index([("id", pymongo.ASCENDING)],  unique=True)
# Out:
# 'id_1'

# %%
query = "scarlett"
crawling_rate = 100000

# %%
search_result = rest_api.search(count=crawling_rate, q=query, tweet_mode="extended", lang='in')
since_id_new = search_result[-1].id
for tweet in search_result:
    try:
        tweet_collection.insert_one(tweet)
    except:
        pass

# %%
since_id_old = 0
count = -1
while(since_id_new != since_id_old):
    since_id_old = since_id_new
    search_result = rest_api.search(count=crawling_rate, q=query, tweet_mode="extended", max_id=since_id_new)
    count+=len(search_result)
    sys.stdout.write("\r");sys.stdout.write("Jumlah tweet yang sudah disimpan %.0f \n" %count);sys.stdout.flush
    since_id_new = search_result[-1].id
    for tweet in search_result:
        try:
            json_str = json.dumps(tweet._json)
            collection.insert_one(tweet._json)
        except:
            pass
# Out:
# Jumlah tweet yang sudah disimpan 78
# Jumlah tweet yang sudah disimpan 158
# Jumlah tweet yang sudah disimpan 253
# Jumlah tweet yang sudah disimpan 338
# Jumlah tweet yang sudah disimpan 425
# Jumlah tweet yang sudah disimpan 498
# Jumlah tweet yang sudah disimpan 598
# Jumlah tweet yang sudah disimpan 697
# Jumlah tweet yang sudah disimpan 767
# Jumlah tweet yang sudah disimpan 832
# Jumlah tweet yang sudah disimpan 904
# Jumlah tweet yang sudah disimpan 994
# Jumlah tweet yang sudah disimpan 1083
# Jumlah tweet yang sudah disimpan 1149
# Jumlah tweet yang sudah disimpan 1205
# Jumlah tweet yang sudah disimpan 1254
# Jumlah tweet yang sudah disimpan 1287
# Jumlah tweet yang sudah disimpan 1328
# Jumlah tweet yang sudah disimpan 1388
# Jumlah tweet yang sudah disimpan 1474
# Jumlah tweet yang sudah disimpan 1574
# Jumlah tweet yang sudah disimpan 1674
# Jumlah tweet yang sudah disimpan 1774
# Jumlah tweet yang sudah disimpan 1874
# Jumlah tweet yang sudah disimpan 1962
# ...

# %%
print(since_id_old)
print(since_id_new)
# Out:
# 1330670695089532929
# 1330670695089532929
