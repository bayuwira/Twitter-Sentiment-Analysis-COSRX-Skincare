# %%
import json
import snscrape.modules.twitter as snstwitter
import tweepy
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db_client = client['cosrx_db']
collection = db_client['crawling_2']

# %%
CONSUMER_KEY = "ER6dm8K9Y2gGm4w3vHhJIxy8o"
CONSUMER_SECRET = "InYaTVJjmIsG3PMp5nKOU6bMUXIyT7kHoJXtVXxsLYh9w1YOS5"
ACCESS_TOKEN = "1330751702136365056-doRSWEBA00wZzOL03hXVMI5qTP2cDe"
ACCESS_TOKEN_SECRET = "ZxCgwpV05w4cjRbUlhPyajUvvSwL5E9bZqVUQxjRTAE1c"

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)
last_id_saver = 'last_id.txt'
if (not api):
    sys.exit('Autentikasi gagal')
else:
    print("Berasil")
# Out:
# Berasil

# %%
count = 0

# %%
for i, tweet in enumerate(snstwitter.TwitterSearchScraper('scarlett + since:2019-05-01 until:2019-06-01 + lang:in').get_items()):
    id = tweet.id
    getTweet = api.get_status(id, wait_on_rate_limit = True)
    json_str = json.dumps(getTweet._json)
    count += 1
    print(count)
    collection.insert_one(getTweet._json)
# Out:
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# ...

# %%
for i, tweet in enumerate(snstwitter.TwitterSearchScraper('skincare cosrx + since:2017-01-01 until:2019-12-02').get_items()):
    if tweet.lang == 'in':
        id = tweet.id
        getTweet = api.get_status(id, wait_on_rate_limit = True)
        json_str = json.dumps(getTweet._json)
        print(json_str)
        collection.insert_one(getTweet._json)
