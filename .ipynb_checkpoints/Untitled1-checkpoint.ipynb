# %%
import json
import snscrape.modules.twitter as snstwitter
import tweepy
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db_client = client['scarlett_db']
collection = db_client['crawling_2']

# %%
CONSUMER_KEY = "ER6dm8K9Y2gGm4w3vHhJIxy8o"
CONSUMER_SECRET = "InYaTVJjmIsG3PMp5nKOU6bMUXIyT7kHoJXtVXxsLYh9w1YOS5"
ACCESS_TOKEN = "1330751702136365056-doRSWEBA00wZzOL03hXVMI5qTP2cDe"
ACCESS_TOKEN_SECRET = "ZxCgwpV05w4cjRbUlhPyajUvvSwL5E9bZqVUQxjRTAE1c"

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
last_id_saver = 'last_id.txt'
if (not api):
    sys.exit('Autentikasi gagal')
else:
    print("Berasil")
# Out:
# Berasil

# %%
count = 9996

# %%
search_words = ['cosrx']
tweets = tweepy.Cursor(api.search, q=search_words, lang="in", since='2018-01-01', tweet_mode='extended').items()
while True:
        # as long as I still have a tweet to grab
        try:
            data = tweets.next()
        except StopIteration:
            break
        # convert from Python dict-like structure to JSON format
        jsoned_data = json.dumps(data._json)
        tweet = json.loads(jsoned_data)
        # insert the information in the database
        collection.insert_one(tweet)
        count += 1
        print('tweet tersimpan : ',  count)
# Out:
# Rate limit reached. Sleeping for: 479

# %%
for i, tweet in enumerate(snstwitter.TwitterSearchScraper('skincare cosrx + since:2018-01-01 until:2020-12-02 + lang:in').get_items()):
    id = tweet.id
    getTweet = api.get_status(id)
    print('berhasil')
    json_str = json.dumps(getTweet._json)
    count += 1
    collection.insert_one(getTweet._json)
    print('tweet tersimpan : ',  count)
# Out:
# berhasil
# tweet tersimpan :  14370
# berhasil
# tweet tersimpan :  14371
# berhasil
# tweet tersimpan :  14372
# berhasil
# tweet tersimpan :  14373
# berhasil
# tweet tersimpan :  14374
# berhasil
# tweet tersimpan :  14375
# berhasil
# tweet tersimpan :  14376
# berhasil
# tweet tersimpan :  14377
# berhasil
# tweet tersimpan :  14378
# berhasil
# tweet tersimpan :  14379
# berhasil
# tweet tersimpan :  14380
# berhasil
# tweet tersimpan :  14381
# berhasil
# tweet tersimpan :  14382
# berhasil
# tweet tersimpan :  14383
# berhasil
# tweet tersimpan :  14384
# berhasil
# tweet tersimpan :  14385
# berhasil
# tweet tersimpan :  14386
# berhasil
# tweet tersimpan :  14387
# berhasil
# tweet tersimpan :  14388
# berhasil
# tweet tersimpan :  14389
# berhasil
# tweet tersimpan :  14390
# berhasil
# tweet tersimpan :  14391
# berhasil
# tweet tersimpan :  14392
# berhasil
# tweet tersimpan :  14393
# berhasil
# tweet tersimpan :  14394
# berhasil
# tweet tersimpan :  14395
# berhasil
# ...

# %%
collection
# Out:
#   File "<ipython-input-15-1a32908918fa>", line 1
#     db.crawling_1.aggregate([ {$group: { _id: "$field_to_search", count: { $sum: 1}}}, {$match: { count: { $gt: 1 }}}])
#                                ^
# SyntaxError: invalid syntax

# %%
collection.find({})
